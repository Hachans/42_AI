# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#        km  price
# 0  240000   3650
# 1  139800   3800
# 2  150500   4400
# 3  185530   4450
# 4  176000   5250

# %%
plt.scatter(df.km, df.price)

# %%
with open('args.json', 'r') as json_file:
    data = json.load(json_file)
theta0 = data['theta0']
theta1 = data['theta1']

# %%
print(theta0, theta1)
# Out:
# -0.02007807020906385 8355.430097177323

# %%
x = df.km
y = theta1 + x * theta0

plt.plot(x, y, 'r')
plt.scatter(df.km, df.price)
plt.xlabel('mileage')
plt.ylabel('price')
plt.show()
